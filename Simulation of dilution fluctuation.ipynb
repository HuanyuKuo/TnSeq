# %%
# Import 

from dilution import * # Source code
from __future__ import division    # Solve problem of division in Python2


# %matplotlib inline

# %%
# Global vars
REPLICA = '1'
STRAIN = 'DivAnc'
MEDIA = 'SC3'
NEUTRAL = 'HO'
BCID_REF = [325789, 325791]

# %%
x = Dilution(REPLICA, STRAIN, MEDIA, BCID_REF, NEUTRAL)
x.runs()
x.plot_scale_freq()
x.plot_ref_strain()
x.plot_s_dist()
# Out:
# N 1453
# Width 0.0256
# Mean -0.00090
# Reference strain slope 0.00284
